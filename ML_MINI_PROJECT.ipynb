# %%
# imports
import pandas as pd
import numpy as np
import math
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
np.random.seed(42)

n = 200

USD = np.random.uniform(80, 90, n)
Crude = np.random.uniform(65, 85, n)
Nifty = np.random.uniform(17500, 19000, n)

Gold = (
    USD * 300 +
    Crude * 50 +
    Nifty * 1.5 +
    np.random.normal(0, 500, n)
)

df = pd.DataFrame({
    'USD': USD,
    'Crude': Crude,
    'Nifty': Nifty,
    'Gold': Gold
})

df = df.round(2)
df.head()
# Out:
#      USD  Crude     Nifty      Gold
# 0  83.75  77.84  17654.69  55232.55
# 1  89.51  66.68  18853.83  58070.59
# 2  87.32  68.23  18257.88  56940.91
# 3  85.99  82.97  18739.69  57536.44
# 4  81.56  77.13  17980.07  55017.77

# %%
X = df[['USD', 'Crude', 'Nifty']]
y = df['Gold']

model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
prediction = model.predict([[8, 74, 18200]])
print("Predicted Gold Price:", prediction[0])
# Out:
# Predicted Gold Price: 56171.38124681482
# C:\Users\VAISHNAVI\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(y, model.predict(X))
plt.xlabel("Actual Gold Price")
plt.ylabel("Predicted Gold Price")
plt.title("Actual vs Predicted Gold Price")
plt.show()
