# %%
import statistics 
li=[1,2,3,3,2,2,1]
print("The average of list values is :",statistics.mean(li))
# Out:
# The average of list values is : 2

# %%
import sys
# !{sys.executable} -m pip install Fraction
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: C:\Users\VAISHNAVI\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\VAISHNAVI\AppData\Local\Programs\Python\Python313\python.exe

# %%
from statistics import median 
from fraction import Fraction as fr

data1 = (2,3,4,5,9,11)
data2 = (2.4,5.1,2.2,-4,8)
data3 = (fr(1,2),fr(3,4),fr(5,6),fr(3,2))
data4 = (-1,-2,-3,-5,-8)
data5 = (-4,-3,-6,-8,7,6,1,3)

print("Median of the data1 is :",median(data1))
print("Median of the data1 is :",median(data2))
print("Median of the data1 is :",median(data3))
print("Median of the data1 is :",median(data4))
print("Median of the data1 is :",median(data5))
# Out:
# Median of the data1 is : 4.5
# Median of the data1 is : 2.4
# Median of the data1 is : 19/24
# Median of the data1 is : -3
# Median of the data1 is : -1.0

# %%
import statistics 

set1 = [1,3,4,5,7]

print("Median of the set is %s" % (statistics.median(set1)))
print("median low of the set is %s" % (statistics.median_low(set1)))
# Out:
# Median of the set is 4
# median low of the set is 4

# %%
import statistics 

set1 = [1,3,4,3,5,7]

print("median of the set %s " % (statistics.median(set1)))
print("Median of the set %s " % (statistics.median_high(set1)))
# Out:
# median of the set 3.5
# Median of the set 4

# %%
#it is the value that has highest frequency in the given data set

# %%
from statistics import mode
from fractions import Fraction as fr

data1 = (2,4,5,5,3,3,3,3,6,6,6,6,7)
data2 = (2.4,3.2,1.3,1.3,2.4,4,6)
data3 = ("red","bule","black","blue","blue")

print("mode of the data1 is :" , mode(data1))
print("mode of the data2 is:", mode(data2))
print("mode if the data3 is :",mode(data3))
# Out:
# mode of the data1 is : 3
# mode of the data2 is: 2.4
# mode if the data3 is : blue

# %%
arr = [1,2,3,4,5]

Maximum=max(arr)
Minimum=min(arr)

Range = Maximum-Minimum
print("Maximum ={}, minimum = {} and Range ={}". format(Maximum,Minimum,Range))
# Out:
# Maximum =5, minimum = 1 and Range =4

# %%
from statistics import variance
from fraction import Fraction as fr

sample1 = (1,2,5,4)
sample2 = (2.4,1.3,1.3,2.4,4.6)

print("MEAN of sample1 is :%s",statistics.mean(sample1))
print("Variance of sample 1 :%s",statistics.variance(sample1))
print("Variance of sample 2 : %s",statistics.variance(sample2))
# Out:
# MEAN of sample1 is :%s 3
# Variance of sample 1 :%s 3.3333333333333335
# Variance of sample 2 : %s 1.8149999999999995
